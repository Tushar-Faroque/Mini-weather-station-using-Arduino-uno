# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('D:\\Tushar Faroque\\Fall-19\\CSE299(ITN)\\Mini-weather-station-using-Arduino-uno\\data3.csv')

# %%
df
# Out:
#                       Date_Time   Temp  Humidity   Air_Quality   Water_Level
# 0    [2019-12-03 12:06:02.808]      21        46           224           202
# 1    [2019-12-03 12:06:02.808]      21        45            90            89
# 2    [2019-12-03 12:06:02.808]      21        45           158           158
# 3    [2019-12-03 12:06:02.808]      21        45            58            58
# 4    [2019-12-03 12:06:02.808]      21        45            58            59
# 5    [2019-12-03 12:06:02.808]      21        45            74            74
# 6    [2019-12-03 12:06:02.808]      21        45            77            77
# 7    [2019-12-03 12:06:02.808]      21        45            88            87
# 8    [2019-12-03 12:06:02.808]      21        45           117           117
# 9    [2019-12-03 12:06:02.808]      21        45            94            94
# 10   [2019-12-03 12:06:02.808]      21        45            85            85
# ...

# %%
df.columns = df.columns.str.strip()
plt.bar(df.Date_Time, df.Air_Quality)
plt.show()

# %%
df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.plot(df.Date_Time, df.Temp)
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.plot(df.Date_Time, df.Humidity)
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.plot(df.Air_Quality, df.Humidity)
plt.show()

# %%
df.columns = df.columns.str.strip()
plt.plot(df.Temp, df.Air_Quality)
plt.show()
